# %% [markdown]
# # Convert image to Verilog code for controlling OLED
#
# *** This Notebook is strictly for the use of Nguyen Van Binh and Nigel Ng. Ask the authors for any further use ***
#
# *Better use offline with Jupyter Notebook so you don't need to upload the images. Just copy the code and ensure that you have all the libraries.*

# %% [markdown]
# # New Section

# %% [markdown]
# Import the libraries.
# numpy, cv2, and PIL are compulsory. IPython is for displaying the image within the Notebook. sys is unneccessary.

# %%
import numpy as np
import cv2
import sys
from PIL import Image
from IPython import display

HEIGHT = 64
WIDTH = 96

# %% [markdown]
# If you run it with Jupyter Notebook on your laptop, just simply type in the route to the image file in filename. If you are using this notebook, upload the image and type in its name.

# %% [markdown]
# This will first resize the image (64x96), normalize the color data, and apply the filter (so there will be less data). If you want to see the image after being processed, uncomment the code snippet at the end of this block. The new image will be saved as "after.png"

# %%
filename = "win.png"
img_bgr = cv2.imread(filename)
img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)


img = cv2.resize(img, (WIDTH, HEIGHT))
print(img.shape)


pixels = list()

for row in range(img.shape[0]):
    for col in range(img.shape[1]):
        # print(img[row][col])
        pixels.append(list(img[row][col]))

# normalize data to fixed bit
for pixel in pixels:
    pixel[0] = int(int(pixel[0] / 256 * 31) / 10) * 10
    pixel[1] = int(int(pixel[1] / 256 * 63) / 20) * 20
    pixel[2] = int(int(pixel[2] / 256 * 31) / 10) * 10
    
# for pixel in pixels:
#     pixel[0] = int(pixel[0] / 30 * 255)
#     pixel[1] = int(pixel[1] / 60 * 255)
#     pixel[2] = int(pixel[2] / 30 * 255)
 
    
# pixels = np.resize(pixels, (64, 96, 3))
# # print(pixels)
# array = np.array(pixels, dtype=np.uint8)
# new_image = Image.fromarray(array)

# new_image.save('after.png')
# new_image.show
# Out:
# (64, 96, 3)

# %% [markdown]
# Run the code below to have Verilog code at the output. Currently, it works best for image with dark background. The colors should also be high contrast. There will be updates for other background colors.

# %% [markdown]
# Copy the code to your stupid Verilog IDE to control the OLED, watch youtube while waiting for the bitstream being created, and feel like a pro after seeing the output.

# %%
# 5 red + 6 green + 5 blue
binary = dict()

for pixel, data in enumerate(pixels):
    if not (data[0] == 0 and data[1] == 0 and data[2] == 0):
        red = '{0:05b}'.format(data[0])
        green = '{0:06b}'.format(data[1])
        blue = '{0:05b}'.format(data[2])

        color = (red + green + blue)
        assert len(color) == 16
        if (color not in binary):
            binary[color] = [pixel]
        else:
            binary[color].append(pixel)   

def interval_extract(list):
    list = sorted(set(list))
    range_start = previous_number = list[0]
    
    for number in list[1:]:
        if number == previous_number + 1:
            previous_number = number
        else:
            yield [range_start, previous_number]
            range_start = previous_number = number
    yield [range_start, previous_number]
    
    
for i, color in enumerate(binary):
  if i != 0:
    print('else if (', end='')
    pixel_ranges = list(interval_extract(binary[color]))
    for i, pixel_range in enumerate(pixel_ranges):
        if i != len(pixel_ranges) - 1:
            if pixel_range[0] == pixel_range[1]:
                print('pixel_index == ' + str(pixel_range[0]) + ' || ', end='')
            else:
                print('((pixel_index >= ' + str(pixel_range[0]) + ') && (pixel_index <= ' + str(pixel_range[1]) + ")) || ", end='')
        else:
            if pixel_range[0] == pixel_range[1]:
                print('pixel_index == ' + str(pixel_range[0]) + ')', end='')
            else:
                print('(pixel_index >= ' + str(pixel_range[0]) + ') && (pixel_index <= ' + str(pixel_range[1]) + '))', end='')
            
    print(" oled_data = 16'b" + color + ';')
  else:
    print('if (', end='')
    pixel_ranges = list(interval_extract(binary[color]))
    for i, pixel_range in enumerate(pixel_ranges):
        if i != len(pixel_ranges) - 1:
            if pixel_range[0] == pixel_range[1]:
                print('pixel_index == ' + str(pixel_range[0]) + ' || ', end='')
            else:
                print('((pixel_index >= ' + str(pixel_range[0]) + ') && (pixel_index <= ' + str(pixel_range[1]) + ")) || ", end='')
        else:
            if pixel_range[0] == pixel_range[1]:
                print('pixel_index == ' + str(pixel_range[0]) + ')', end='')
            else:
                print('(pixel_index >= ' + str(pixel_range[0]) + ') && (pixel_index <= ' + str(pixel_range[1]) + '))', end='')
            
    print(" oled_data = 16'b" + color + ';')

print("else oled_data = 0;")
# Out:
# if (((pixel_index >= 2538) && (pixel_index <= 2539)) || pixel_index == 2732 || pixel_index == 2735 || pixel_index == 2826 || ((pixel_index >= 2919) && (pixel_index <= 2920)) || ((pixel_index >= 2923) && (pixel_index <= 2924)) || pixel_index == 2926 || pixel_index == 2930 || ((pixel_index >= 3012) && (pixel_index <= 3015)) || pixel_index == 3021 || pixel_index == 3026 || ((pixel_index >= 3108) && (pixel_index <= 3109)) || pixel_index == 3212 || pixel_index == 3315 || pixel_index == 3415 || pixel_index == 3498 || pixel_index == 3512 || pixel_index == 3591 || pixel_index == 3599 || pixel_index == 3686 || pixel_index == 3875 || pixel_index == 3883 || pixel_index == 3974 || pixel_index == 3979 || pixel_index == 3993 || ((pixel_index >= 4070) && (pixel_index <= 4071)) || ((pixel_index >= 4073) && (pixel_index <= 4075)) || pixel_index == 4163 || pixel_index == 4166 || ((pixel_index >= 4169) && (pixel_index <= 4171)) || pixel_index == 4262 || ((pixel_index >= 4265) && (pixel_index <= 4267)) || pixel_index == 4282 || ((pixel_index >= 4362) && (pixel_index <= 4363)) || pixel_index == 4475 || pixel_index == 4550 || pixel_index == 4561 || pixel_index == 4657 || pixel_index == 4753 || pixel_index == 4766 || pixel_index == 4838 || pixel_index == 4844 || pixel_index == 4849 || pixel_index == 4940 || pixel_index == 4945 || pixel_index == 5031 || pixel_index == 5036 || ((pixel_index >= 5040) && (pixel_index <= 5041)) || pixel_index == 5127 || pixel_index == 5132 || ((pixel_index >= 5136) && (pixel_index <= 5137)) || pixel_index == 5154 || pixel_index == 5228 || ((pixel_index >= 5232) && (pixel_index <= 5233)) || pixel_index == 5250 || pixel_index == 5324 || ((pixel_index >= 5327) && (pixel_index <= 5329)) || pixel_index == 5345 || pixel_index == 5414 || pixel_index == 5419 || ((pixel_index >= 5423) && (pixel_index <= 5425)) || ((pixel_index >= 5439) && (pixel_index <= 5440)) || pixel_index == 5442 || pixel_index == 5510 || ((pixel_index >= 5515) && (pixel_index <= 5516)) || (pixel_index >= 5532) && (pixel_index <= 5536)) oled_data = 16'b0101000000000000;
# else if (pixel_index == 2633) oled_data = 16'b1010000000000000;
# else if (((pixel_index >= 2634) && (pixel_index <= 2635)) || pixel_index == 2731 || pixel_index == 2825 || pixel_index == 2931 || ((pixel_index >= 3018) && (pixel_index <= 3019)) || pixel_index == 3030 || pixel_index == 3114 || pixel_index == 3116 || pixel_index == 3123 || pixel_index == 3126 || pixel_index == 3211 || pixel_index == 3214 || pixel_index == 3222 || pixel_index == 3306 || pixel_index == 3308 || pixel_index == 3316 || pixel_index == 3318 || pixel_index == 3396 || pixel_index == 3398 || ((pixel_index >= 3402) && (pixel_index <= 3403)) || pixel_index == 3405 || ((pixel_index >= 3412) && (pixel_index <= 3413)) || pixel_index == 3492 || ((pixel_index >= 3494) && (pixel_index <= 3495)) || pixel_index == 3497 || ((pixel_index >= 3499) && (pixel_index <= 3501)) || pixel_index == 3503 || pixel_index == 3507 || ((pixel_index >= 3509) && (pixel_index <= 3510)) || pixel_index == 3590 || pixel_index == 3592 || ((pixel_index >= 3594) && (pixel_index <= 3595)) || pixel_index == 3597 || pixel_index == 3602 || ((pixel_index >= 3605) && (pixel_index <= 3606)) || ((pixel_index >= 3688) && (pixel_index <= 3690)) || pixel_index == 3693 || ((pixel_index >= 3785) && (pixel_index <= 3787)) || pixel_index == 3791 || pixel_index == 3798 || pixel_index == 3877 || ((pixel_index >= 3886) && (pixel_index <= 3887)) || pixel_index == 3972 || ((pixel_index >= 3981) && (pixel_index <= 3984)) || pixel_index == 4068 || pixel_index == 4079 || pixel_index == 4164 || pixel_index == 4175 || ((pixel_index >= 4260) && (pixel_index <= 4261)) || pixel_index == 4271 || ((pixel_index >= 4356) && (pixel_index <= 4357)) || pixel_index == 4366 || pixel_index == 4461 || pixel_index == 4549) oled_data = 16'b1010001010001010;
# else if (pixel_index == 2636 || pixel_index == 2935 || pixel_index == 3110 || pixel_index == 3300 || pixel_index == 3407 || pixel_index == 3593 || pixel_index == 3596 || pixel_index == 3698 || pixel_index == 3784 || pixel_index == 3789 || ((pixel_index >= 3880) && (pixel_index <= 3881)) || pixel_index == 3885 || pixel_index == 3971 || ((pixel_index >= 3976) && (pixel_index <= 3977)) || pixel_index == 4067 || pixel_index == 4072 || pixel_index == 4077 || pixel_index == 4168 || pixel_index == 4264 || ((pixel_index >= 4359) && (pixel_index <= 4361)) || pixel_index == 4367 || ((pixel_index >= 4455) && (pixel_index <= 4457)) || pixel_index == 4459 || ((pixel_index >= 4551) && (pixel_index <= 4552)) || ((pixel_index >= 4555) && (pixel_index <= 4556)) || ((pixel_index >= 4647) && (pixel_index <= 4648)) || ((pixel_index >= 4651) && (pixel_index <= 4652)) || ((pixel_index >= 4742) && (pixel_index <= 4744)) || ((pixel_index >= 4747) && (pixel_index <= 4748)) || pixel_index == 4839 || pixel_index == 4843 || pixel_index == 4934 || pixel_index == 5030) oled_data = 16'b0101001010000000;
# else if (((pixel_index >= 2729) && (pixel_index <= 2730)) || pixel_index == 2824 || pixel_index == 2827 || ((pixel_index >= 2835) && (pixel_index <= 2838)) || pixel_index == 2922 || pixel_index == 2934 || pixel_index == 3031 || pixel_index == 3127 || pixel_index == 3223 || pixel_index == 3319 || pixel_index == 3411 || pixel_index == 3414 || pixel_index == 3695 || pixel_index == 4452 || pixel_index == 4454 || pixel_index == 4558 || pixel_index == 4935 || pixel_index == 4939 || pixel_index == 5035 || pixel_index == 5126 || pixel_index == 5131 || pixel_index == 5222 || pixel_index == 5227 || pixel_index == 5318 || pixel_index == 5323) oled_data = 16'b1010001010000000;
# else if (pixel_index == 2921 || ((pixel_index >= 3016) && (pixel_index <= 3017)) || ((pixel_index >= 3111) && (pixel_index <= 3113)) || pixel_index == 3115 || ((pixel_index >= 3205) && (pixel_index <= 3210)) || pixel_index == 3213 || ((pixel_index >= 3301) && (pixel_index <= 3305)) || ((pixel_index >= 3309) && (pixel_index <= 3310)) || pixel_index == 3397 || ((pixel_index >= 3399) && (pixel_index <= 3401)) || pixel_index == 3404 || pixel_index == 3406 || pixel_index == 3493 || pixel_index == 3496 || pixel_index == 3502 || ((pixel_index >= 3588) && (pixel_index <= 3589)) || pixel_index == 3598 || ((pixel_index >= 3684) && (pixel_index <= 3685)) || pixel_index == 3691 || pixel_index == 3694 || ((pixel_index >= 3780) && (pixel_index <= 3781)) || pixel_index == 3790 || pixel_index == 3876 || pixel_index == 3973 || pixel_index == 4069 || pixel_index == 4078 || pixel_index == 4165 || pixel_index == 4174 || pixel_index == 4270 || pixel_index == 4453 || pixel_index == 4462) oled_data = 16'b1111001010001010;
# else if (((pixel_index >= 2932) && (pixel_index <= 2933)) || pixel_index == 3027 || pixel_index == 3221) oled_data = 16'b1010010100001010;
# else if (((pixel_index >= 3028) && (pixel_index <= 3029)) || ((pixel_index >= 3124) && (pixel_index <= 3125)) || pixel_index == 3220 || pixel_index == 3317) oled_data = 16'b1010010100010100;
# else if (pixel_index == 3117 || pixel_index == 3219 || pixel_index == 3307 || pixel_index == 3794 || pixel_index == 3882 || pixel_index == 3978 || pixel_index == 3990 || pixel_index == 4080 || pixel_index == 4086 || pixel_index == 4184 || pixel_index == 4280) oled_data = 16'b0101001010001010;
# else if (pixel_index == 3506 || pixel_index == 3604 || pixel_index == 3608 || pixel_index == 3697 || pixel_index == 3704 || pixel_index == 3793 || pixel_index == 3797 || pixel_index == 3890 || pixel_index == 3897 || pixel_index == 4089 || pixel_index == 4281 || pixel_index == 4377 || pixel_index == 4568 || pixel_index == 4752 || pixel_index == 4762 || pixel_index == 4848 || ((pixel_index >= 4859) && (pixel_index <= 4860)) || pixel_index == 4863 || ((pixel_index >= 4943) && (pixel_index <= 4944)) || pixel_index == 4956 || pixel_index == 5053 || pixel_index == 5058 || pixel_index == 5231 || pixel_index == 5246 || pixel_index == 5249 || pixel_index == 5422 || pixel_index == 5441) oled_data = 16'b0101000000001010;
# else if (pixel_index == 3508 || pixel_index == 3511 || pixel_index == 3607 || ((pixel_index >= 3701) && (pixel_index <= 3703)) || ((pixel_index >= 3799) && (pixel_index <= 3800)) || ((pixel_index >= 3894) && (pixel_index <= 3896)) || ((pixel_index >= 3991) && (pixel_index <= 3992)) || pixel_index == 4088 || pixel_index == 4185 || pixel_index == 4378 || pixel_index == 4474 || ((pixel_index >= 4569) && (pixel_index <= 4571)) || ((pixel_index >= 4665) && (pixel_index <= 4668)) || ((pixel_index >= 4763) && (pixel_index <= 4765)) || ((pixel_index >= 4861) && (pixel_index <= 4862)) || ((pixel_index >= 4957) && (pixel_index <= 4960)) || pixel_index == 5039 || ((pixel_index >= 5054) && (pixel_index <= 5057)) || ((pixel_index >= 5134) && (pixel_index <= 5135)) || ((pixel_index >= 5150) && (pixel_index <= 5153)) || pixel_index == 5230 || ((pixel_index >= 5247) && (pixel_index <= 5248)) || pixel_index == 5326 || (pixel_index >= 5343) && (pixel_index <= 5344)) oled_data = 16'b1010000000001010;
# else if (pixel_index == 3889 || pixel_index == 4087 || pixel_index == 4183 || pixel_index == 4376 || pixel_index == 4472) oled_data = 16'b0101010100010100;
# else if (pixel_index == 3985 || pixel_index == 4473) oled_data = 16'b0101001010010100;
# else if (pixel_index == 4082 || ((pixel_index >= 4084) && (pixel_index <= 4085)) || ((pixel_index >= 4178) && (pixel_index <= 4182)) || ((pixel_index >= 4274) && (pixel_index <= 4278)) || ((pixel_index >= 4369) && (pixel_index <= 4375)) || ((pixel_index >= 4465) && (pixel_index <= 4471)) || ((pixel_index >= 4562) && (pixel_index <= 4567)) || ((pixel_index >= 4658) && (pixel_index <= 4664)) || ((pixel_index >= 4754) && (pixel_index <= 4761)) || ((pixel_index >= 4850) && (pixel_index <= 4858)) || ((pixel_index >= 4946) && (pixel_index <= 4955)) || ((pixel_index >= 5042) && (pixel_index <= 5052)) || ((pixel_index >= 5138) && (pixel_index <= 5149)) || ((pixel_index >= 5234) && (pixel_index <= 5245)) || ((pixel_index >= 5330) && (pixel_index <= 5342)) || ((pixel_index >= 5426) && (pixel_index <= 5437)) || (pixel_index >= 5528) && (pixel_index <= 5531)) oled_data = 16'b0000000000001010;
# else if (pixel_index == 4279) oled_data = 16'b0000001010001010;
# else oled_data = 0;

# %%
new = dict()

for i in binary:
  if (i != '0000000000000000'):
    new[i] = binary[i]

print(new)
# Out:
# {'0101000000000000': [2538, 2539, 2732, 2735, 2826, 2919, 2920, 2923, 2924, 2926, 2930, 3012, 3013, 3014, 3015, 3021, 3026, 3108, 3109, 3212, 3315, 3415, 3498, 3512, 3591, 3599, 3686, 3875, 3883, 3974, 3979, 3993, 4070, 4071, 4073, 4074, 4075, 4163, 4166, 4169, 4170, 4171, 4262, 4265, 4266, 4267, 4282, 4362, 4363, 4475, 4550, 4561, 4657, 4753, 4766, 4838, 4844, 4849, 4940, 4945, 5031, 5036, 5040, 5041, 5127, 5132, 5136, 5137, 5154, 5228, 5232, 5233, 5250, 5324, 5327, 5328, 5329, 5345, 5414, 5419, 5423, 5424, 5425, 5439, 5440, 5442, 5510, 5515, 5516, 5532, 5533, 5534, 5535, 5536], '1010000000000000': [2633], '1010001010001010': [2634, 2635, 2731, 2825, 2931, 3018, 3019, 3030, 3114, 3116, 3123, 3126, 3211, 3214, 3222, 3306, 3308, 3316, 3318, 3396, 3398, 3402, 3403, 3405, 3412, 3413, 3492, 3494, 3495, 3497, 3499, 3500, 3501, 3503, 3507, 3509, 3510, 3590, 3592, 3594, 3595, 3597, 3602, 3605, 3606, 3688, 3689, 3690, 3693, 3785, 3786, 3787, 3791, 3798, 3877, 3886, 3887, 3972, 3981, 3982, 3983, 3984, 4068, 4079, 4164, 4175, 4260, 4261, 4271, 4356, 4357, 4366, 4461, 4549], '0101001010000000': [2636, 2935, 3110, 3300, 3407, 3593, 3596, 3698, 3784, 3789, 3880, 3881, 3885, 3971, 3976, 3977, 4067, 4072, 4077, 4168, 4264, 4359, 4360, 4361, 4367, 4455, 4456, 4457, 4459, 4551, 4552, 4555, 4556, 4647, 4648, 4651, 4652, 4742, 4743, 4744, 4747, 4748, 4839, 4843, 4934, 5030], '1010001010000000': [2729, 2730, 2824, 2827, 2835, 2836, 2837, 2838, 2922, 2934, 3031, 3127, 3223, 3319, 3411, 3414, 3695, 4452, 4454, 4558, 4935, 4939, 5035, 5126, 5131, 5222, 5227, 5318, 5323], '1111001010001010': [2921, 3016, 3017, 3111, 3112, 3113, 3115, 3205, 3206, 3207, 3208, 3209, 3210, 3213, 3301, 3302, 3303, 3304, 3305, 3309, 3310, 3397, 3399, 3400, 3401, 3404, 3406, 3493, 3496, 3502, 3588, 3589, 3598, 3684, 3685, 3691, 3694, 3780, 3781, 3790, 3876, 3973, 4069, 4078, 4165, 4174, 4270, 4453, 4462], '1010010100001010': [2932, 2933, 3027, 3221], '1010010100010100': [3028, 3029, 3124, 3125, 3220, 3317], '0101001010001010': [3117, 3219, 3307, 3794, 3882, 3978, 3990, 4080, 4086, 4184, 4280], '0101000000001010': [3506, 3604, 3608, 3697, 3704, 3793, 3797, 3890, 3897, 4089, 4281, 4377, 4568, 4752, 4762, 4848, 4859, 4860, 4863, 4943, 4944, 4956, 5053, 5058, 5231, 5246, 5249, 5422, 5441], '1010000000001010': [3508, 3511, 3607, 3701, 3702, 3703, 3799, 3800, 3894, 3895, 3896, 3991, 3992, 4088, 4185, 4378, 4474, 4569, 4570, 4571, 4665, 4666, 4667, 4668, 4763, 4764, 4765, 4861, 4862, 4957, 4958, 4959, 4960, 5039, 5054, 5055, 5056, 5057, 5134, 5135, 5150, 5151, 5152, 5153, 5230, 5247, 5248, 5326, 5343, 5344], '0101010100010100': [3889, 4087, 4183, 4376, 4472], '0101001010010100': [3985, 4473], '0000000000001010': [4082, 4084, 4085, 4178, 4179, 4180, 4181, 4182, 4274, 4275, 4276, 4277, 4278, 4369, 4370, 4371, 4372, 4373, 4374, 4375, 4465, 4466, 4467, 4468, 4469, 4470, 4471, 4562, 4563, 4564, 4565, 4566, 4567, 4658, 4659, 4660, 4661, 4662, 4663, 4664, 4754, 4755, 4756, 4757, 4758, 4759, 4760, 4761, 4850, 4851, 4852, 4853, 4854, 4855, 4856, 4857, 4858, 4946, 4947, 4948, 4949, 4950, 4951, 4952, 4953, 4954, 4955, 5042, 5043, 5044, 5045, 5046, 5047, 5048, 5049, 5050, 5051, 5052, 5138, 5139, 5140, 5141, 5142, 5143, 5144, 5145, 5146, 5147, 5148, 5149, 5234, 5235, 5236, 5237, 5238, 5239, 5240, 5241, 5242, 5243, 5244, 5245, 5330, 5331, 5332, 5333, 5334, 5335, 5336, 5337, 5338, 5339, 5340, 5341, 5342, 5426, 5427, 5428, 5429, 5430, 5431, 5432, 5433, 5434, 5435, 5436, 5437, 5528, 5529, 5530, 5531], '0000001010001010': [4279]}

# %%
def coordinate(pixel):
  x = pixel % 96
  y = pixel // 96
  return (x,y)

pic = dict()

for color in new:
  pic[color] = list()
  for pixel in new[color]:
    pic[color].append(coordinate(pixel))

for color in pic:
  print(color + str(pic[color]))
# Out:
# 0101000000000000[(42, 26), (43, 26), (44, 28), (47, 28), (42, 29), (39, 30), (40, 30), (43, 30), (44, 30), (46, 30), (50, 30), (36, 31), (37, 31), (38, 31), (39, 31), (45, 31), (50, 31), (36, 32), (37, 32), (44, 33), (51, 34), (55, 35), (42, 36), (56, 36), (39, 37), (47, 37), (38, 38), (35, 40), (43, 40), (38, 41), (43, 41), (57, 41), (38, 42), (39, 42), (41, 42), (42, 42), (43, 42), (35, 43), (38, 43), (41, 43), (42, 43), (43, 43), (38, 44), (41, 44), (42, 44), (43, 44), (58, 44), (42, 45), (43, 45), (59, 46), (38, 47), (49, 47), (49, 48), (49, 49), (62, 49), (38, 50), (44, 50), (49, 50), (44, 51), (49, 51), (39, 52), (44, 52), (48, 52), (49, 52), (39, 53), (44, 53), (48, 53), (49, 53), (66, 53), (44, 54), (48, 54), (49, 54), (66, 54), (44, 55), (47, 55), (48, 55), (49, 55), (65, 55), (38, 56), (43, 56), (47, 56), (48, 56), (49, 56), (63, 56), (64, 56), (66, 56), (38, 57), (43, 57), (44, 57), (60, 57), (61, 57), (62, 57), (63, 57), (64, 57)]
# 1010000000000000[(41, 27)]
# 1010001010001010[(42, 27), (43, 27), (43, 28), (41, 29), (51, 30), (42, 31), (43, 31), (54, 31), (42, 32), (44, 32), (51, 32), (54, 32), (43, 33), (46, 33), (54, 33), (42, 34), (44, 34), (52, 34), (54, 34), (36, 35), (38, 35), (42, 35), (43, 35), (45, 35), (52, 35), (53, 35), (36, 36), (38, 36), (39, 36), (41, 36), (43, 36), (44, 36), (45, 36), (47, 36), (51, 36), (53, 36), (54, 36), (38, 37), (40, 37), (42, 37), (43, 37), (45, 37), (50, 37), (53, 37), (54, 37), (40, 38), (41, 38), (42, 38), (45, 38), (41, 39), (42, 39), (43, 39), (47, 39), (54, 39), (37, 40), (46, 40), (47, 40), (36, 41), (45, 41), (46, 41), (47, 41), (48, 41), (36, 42), (47, 42), (36, 43), (47, 43), (36, 44), (37, 44), (47, 44), (36, 45), (37, 45), (46, 45), (45, 46), (37, 47)]
# 0101001010000000[(44, 27), (55, 30), (38, 32), (36, 34), (47, 35), (41, 37), (44, 37), (50, 38), (40, 39), (45, 39), (40, 40), (41, 40), (45, 40), (35, 41), (40, 41), (41, 41), (35, 42), (40, 42), (45, 42), (40, 43), (40, 44), (39, 45), (40, 45), (41, 45), (47, 45), (39, 46), (40, 46), (41, 46), (43, 46), (39, 47), (40, 47), (43, 47), (44, 47), (39, 48), (40, 48), (43, 48), (44, 48), (38, 49), (39, 49), (40, 49), (43, 49), (44, 49), (39, 50), (43, 50), (38, 51), (38, 52)]
# 1010001010000000[(41, 28), (42, 28), (40, 29), (43, 29), (51, 29), (52, 29), (53, 29), (54, 29), (42, 30), (54, 30), (55, 31), (55, 32), (55, 33), (55, 34), (51, 35), (54, 35), (47, 38), (36, 46), (38, 46), (46, 47), (39, 51), (43, 51), (43, 52), (38, 53), (43, 53), (38, 54), (43, 54), (38, 55), (43, 55)]
# 1111001010001010[(41, 30), (40, 31), (41, 31), (39, 32), (40, 32), (41, 32), (43, 32), (37, 33), (38, 33), (39, 33), (40, 33), (41, 33), (42, 33), (45, 33), (37, 34), (38, 34), (39, 34), (40, 34), (41, 34), (45, 34), (46, 34), (37, 35), (39, 35), (40, 35), (41, 35), (44, 35), (46, 35), (37, 36), (40, 36), (46, 36), (36, 37), (37, 37), (46, 37), (36, 38), (37, 38), (43, 38), (46, 38), (36, 39), (37, 39), (46, 39), (36, 40), (37, 41), (37, 42), (46, 42), (37, 43), (46, 43), (46, 44), (37, 46), (46, 46)]
# 1010010100001010[(52, 30), (53, 30), (51, 31), (53, 33)]
# 1010010100010100[(52, 31), (53, 31), (52, 32), (53, 32), (52, 33), (53, 34)]
# 0101001010001010[(45, 32), (51, 33), (43, 34), (50, 39), (42, 40), (42, 41), (54, 41), (48, 42), (54, 42), (56, 43), (56, 44)]
# 0101000000001010[(50, 36), (52, 37), (56, 37), (49, 38), (56, 38), (49, 39), (53, 39), (50, 40), (57, 40), (57, 42), (57, 44), (57, 45), (56, 47), (48, 49), (58, 49), (48, 50), (59, 50), (60, 50), (63, 50), (47, 51), (48, 51), (60, 51), (61, 52), (66, 52), (47, 54), (62, 54), (65, 54), (46, 56), (65, 56)]
# 1010000000001010[(52, 36), (55, 36), (55, 37), (53, 38), (54, 38), (55, 38), (55, 39), (56, 39), (54, 40), (55, 40), (56, 40), (55, 41), (56, 41), (56, 42), (57, 43), (58, 45), (58, 46), (57, 47), (58, 47), (59, 47), (57, 48), (58, 48), (59, 48), (60, 48), (59, 49), (60, 49), (61, 49), (61, 50), (62, 50), (61, 51), (62, 51), (63, 51), (64, 51), (47, 52), (62, 52), (63, 52), (64, 52), (65, 52), (46, 53), (47, 53), (62, 53), (63, 53), (64, 53), (65, 53), (46, 54), (63, 54), (64, 54), (46, 55), (63, 55), (64, 55)]
# 0101010100010100[(49, 40), (55, 42), (55, 43), (56, 45), (56, 46)]
# 0101001010010100[(49, 41), (57, 46)]
# 0000000000001010[(50, 42), (52, 42), (53, 42), (50, 43), (51, 43), (52, 43), (53, 43), (54, 43), (50, 44), (51, 44), (52, 44), (53, 44), (54, 44), (49, 45), (50, 45), (51, 45), (52, 45), (53, 45), (54, 45), (55, 45), (49, 46), (50, 46), (51, 46), (52, 46), (53, 46), (54, 46), (55, 46), (50, 47), (51, 47), (52, 47), (53, 47), (54, 47), (55, 47), (50, 48), (51, 48), (52, 48), (53, 48), (54, 48), (55, 48), (56, 48), (50, 49), (51, 49), (52, 49), (53, 49), (54, 49), (55, 49), (56, 49), (57, 49), (50, 50), (51, 50), (52, 50), (53, 50), (54, 50), (55, 50), (56, 50), (57, 50), (58, 50), (50, 51), (51, 51), (52, 51), (53, 51), (54, 51), (55, 51), (56, 51), (57, 51), (58, 51), (59, 51), (50, 52), (51, 52), (52, 52), (53, 52), (54, 52), (55, 52), (56, 52), (57, 52), (58, 52), (59, 52), (60, 52), (50, 53), (51, 53), (52, 53), (53, 53), (54, 53), (55, 53), (56, 53), (57, 53), (58, 53), (59, 53), (60, 53), (61, 53), (50, 54), (51, 54), (52, 54), (53, 54), (54, 54), (55, 54), (56, 54), (57, 54), (58, 54), (59, 54), (60, 54), (61, 54), (50, 55), (51, 55), (52, 55), (53, 55), (54, 55), (55, 55), (56, 55), (57, 55), (58, 55), (59, 55), (60, 55), (61, 55), (62, 55), (50, 56), (51, 56), (52, 56), (53, 56), (54, 56), (55, 56), (56, 56), (57, 56), (58, 56), (59, 56), (60, 56), (61, 56), (56, 57), (57, 57), (58, 57), (59, 57)]
# 0000001010001010[(55, 44)]

# %%
statement = ''

for color in pic:
  statement += 'else if ('
  for (x,y) in pic[color]:
      statement += ('((x == ' + str(x) + ' + x_white) && (y == ' + str(y) + ' + y_white)) || ')
  
  statement = statement[:-4] + (") oled_data = 16'b" + color + '; ')

print(statement)
# Out:
# else if (((x == 42 + x_white) && (y == 26 + y_white)) || ((x == 43 + x_white) && (y == 26 + y_white)) || ((x == 44 + x_white) && (y == 28 + y_white)) || ((x == 47 + x_white) && (y == 28 + y_white)) || ((x == 42 + x_white) && (y == 29 + y_white)) || ((x == 39 + x_white) && (y == 30 + y_white)) || ((x == 40 + x_white) && (y == 30 + y_white)) || ((x == 43 + x_white) && (y == 30 + y_white)) || ((x == 44 + x_white) && (y == 30 + y_white)) || ((x == 46 + x_white) && (y == 30 + y_white)) || ((x == 50 + x_white) && (y == 30 + y_white)) || ((x == 36 + x_white) && (y == 31 + y_white)) || ((x == 37 + x_white) && (y == 31 + y_white)) || ((x == 38 + x_white) && (y == 31 + y_white)) || ((x == 39 + x_white) && (y == 31 + y_white)) || ((x == 45 + x_white) && (y == 31 + y_white)) || ((x == 50 + x_white) && (y == 31 + y_white)) || ((x == 36 + x_white) && (y == 32 + y_white)) || ((x == 37 + x_white) && (y == 32 + y_white)) || ((x == 44 + x_white) && (y == 33 + y_white)) || ((x == 51 + x_white) && (y == 34 + y_white)) || ((x == 55 + x_white) && (y == 35 + y_white)) || ((x == 42 + x_white) && (y == 36 + y_white)) || ((x == 56 + x_white) && (y == 36 + y_white)) || ((x == 39 + x_white) && (y == 37 + y_white)) || ((x == 47 + x_white) && (y == 37 + y_white)) || ((x == 38 + x_white) && (y == 38 + y_white)) || ((x == 35 + x_white) && (y == 40 + y_white)) || ((x == 43 + x_white) && (y == 40 + y_white)) || ((x == 38 + x_white) && (y == 41 + y_white)) || ((x == 43 + x_white) && (y == 41 + y_white)) || ((x == 57 + x_white) && (y == 41 + y_white)) || ((x == 38 + x_white) && (y == 42 + y_white)) || ((x == 39 + x_white) && (y == 42 + y_white)) || ((x == 41 + x_white) && (y == 42 + y_white)) || ((x == 42 + x_white) && (y == 42 + y_white)) || ((x == 43 + x_white) && (y == 42 + y_white)) || ((x == 35 + x_white) && (y == 43 + y_white)) || ((x == 38 + x_white) && (y == 43 + y_white)) || ((x == 41 + x_white) && (y == 43 + y_white)) || ((x == 42 + x_white) && (y == 43 + y_white)) || ((x == 43 + x_white) && (y == 43 + y_white)) || ((x == 38 + x_white) && (y == 44 + y_white)) || ((x == 41 + x_white) && (y == 44 + y_white)) || ((x == 42 + x_white) && (y == 44 + y_white)) || ((x == 43 + x_white) && (y == 44 + y_white)) || ((x == 58 + x_white) && (y == 44 + y_white)) || ((x == 42 + x_white) && (y == 45 + y_white)) || ((x == 43 + x_white) && (y == 45 + y_white)) || ((x == 59 + x_white) && (y == 46 + y_white)) || ((x == 38 + x_white) && (y == 47 + y_white)) || ((x == 49 + x_white) && (y == 47 + y_white)) || ((x == 49 + x_white) && (y == 48 + y_white)) || ((x == 49 + x_white) && (y == 49 + y_white)) || ((x == 62 + x_white) && (y == 49 + y_white)) || ((x == 38 + x_white) && (y == 50 + y_white)) || ((x == 44 + x_white) && (y == 50 + y_white)) || ((x == 49 + x_white) && (y == 50 + y_white)) || ((x == 44 + x_white) && (y == 51 + y_white)) || ((x == 49 + x_white) && (y == 51 + y_white)) || ((x == 39 + x_white) && (y == 52 + y_white)) || ((x == 44 + x_white) && (y == 52 + y_white)) || ((x == 48 + x_white) && (y == 52 + y_white)) || ((x == 49 + x_white) && (y == 52 + y_white)) || ((x == 39 + x_white) && (y == 53 + y_white)) || ((x == 44 + x_white) && (y == 53 + y_white)) || ((x == 48 + x_white) && (y == 53 + y_white)) || ((x == 49 + x_white) && (y == 53 + y_white)) || ((x == 66 + x_white) && (y == 53 + y_white)) || ((x == 44 + x_white) && (y == 54 + y_white)) || ((x == 48 + x_white) && (y == 54 + y_white)) || ((x == 49 + x_white) && (y == 54 + y_white)) || ((x == 66 + x_white) && (y == 54 + y_white)) || ((x == 44 + x_white) && (y == 55 + y_white)) || ((x == 47 + x_white) && (y == 55 + y_white)) || ((x == 48 + x_white) && (y == 55 + y_white)) || ((x == 49 + x_white) && (y == 55 + y_white)) || ((x == 65 + x_white) && (y == 55 + y_white)) || ((x == 38 + x_white) && (y == 56 + y_white)) || ((x == 43 + x_white) && (y == 56 + y_white)) || ((x == 47 + x_white) && (y == 56 + y_white)) || ((x == 48 + x_white) && (y == 56 + y_white)) || ((x == 49 + x_white) && (y == 56 + y_white)) || ((x ==  ...
